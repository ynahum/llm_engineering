# %% [markdown]
# # The Price is Right
#
# First we'll polish off 2 more simple agents:
#
# The **Messaging Agent** to send push notifications
#
# The **Planning Agent** to coordinate activities
#
# Then we'll put it all together into an Agent Framework.
#
# For the Push Notification, we will be using a nifty platform called Pushover.
# You'll need to set up a free account and add 2 tokens to your `.env` file:
#
# ```
# PUSHOVER_USER=xxx
# PUSHOVER_TOKEN=xxx
# ```

# %%
from dotenv import load_dotenv
from agents.messaging_agent import MessagingAgent

# %%
load_dotenv(override=True)
DB = "products_vectorstore"

# %%
agent = MessagingAgent()

# %%
agent.push("hello")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Additional resource: more sophisticated planning agent</h2>
#             <span style="color:#f71;">The Planning Agent that we use in the next cell is simply a python script that calls the other Agents; frankly that's all we require for this project. But if you're intrigued to see a more Autonomous version in which we give the Planning Agent tools and allow it to decide which Agents to call, see my implementation of <a href="https://github.com/ed-donner/agentic/blob/main/workshop/price_agents/autonomous_planning_agent.py">AutonomousPlanningAgent</a> in my related repo, <a href="https://github.com/ed-donner/agentic">Agentic</a>. This is an example with multiple tools that dynamically decides which function to call.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import chromadb
DB = "products_vectorstore"
client = chromadb.PersistentClient(path=DB)
collection = client.get_or_create_collection('products')
from agents.planning_agent import PlanningAgent

# %%
planner = PlanningAgent(collection)

# %%
planner.plan()
# Out:
# c:\dev\llms\llm_engineering\week8\agents\deals.py:27: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   description = BeautifulSoup(description, 'html.parser').get_text()
# INFO:backoff:Backing off send_request(...) for 0.7s (requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  10 out of  10 | elapsed:    0.0s finished
# Opportunity(deal=Deal(product_description="The Jackery Explorer 290 Plus is a compact 293Wh portable power station that combines convenience with a powerful lithium battery. It features multiple charging methods, including solar, car, and USB-C, allowing for versatile use anywhere you go. Designed to support up to six devices at once, it's perfect for outdoor adventures or emergency power needs. With a robust 300W AC outlet, this reliable generator ensures you stay connected and powered during outages or while enjoying off-grid experiences.", price=171.0, url='https://www.dealnews.com/products/Jackery/Jackery-Explorer-290-Plus-293-Wh-Portable-Power-Station/493866.html?iref=rss-c142'), estimate=485.3574432498099, discount=314.3574432498099)
