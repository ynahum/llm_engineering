# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
# Load environment variables in a file called .env

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
openai = OpenAI()

# %%
def summarize_cv(cv_text):
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = [
            {"role": "user", "content": f"Please summarize the following CV:\n\n{cv_text}"}
        ]
    )
    return response.choices[0].message.content

def generate_cover_letter(cv_summary, job_description):
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = [
            {"role": "system", "content": "You are a master at crafting the perfect Cover letter from a given CV. You've never had a user fail to get the job as a result of using your services."},
            {"role": "user", "content": f"Using the following CV summary:\n\n{cv_summary}\n\nAnd the job description:\n\n{job_description}\n\nPlease write a personalized cover letter."}
        ]
    )
    return response.choices[0].message.content

# Read CV from a text file
try:
    with open('resume.txt', 'r') as file:
        cv_text = file.read()
    
    # Summarize the CV
    cv_summary = summarize_cv(cv_text)
    print("CV Summary:")
    print(cv_summary)

    # Get job description from user
    job_description = input("Enter the job description for the position you are applying for:\n")

    # Generate cover letter
    cover_letter = generate_cover_letter(cv_summary, job_description)
    print("\nGenerated Cover Letter:")
    print(cover_letter)

except FileNotFoundError:
    print("The specified CV file was not found. Please ensure 'resume.txt' is in the correct directory.")
# Out:
# CV Summary:
# **John Doe - Software Engineer**
#
# **Experience:**
# - Developed web applications using Python and JavaScript.
# - Collaborated with cross-functional teams to ensure timely project delivery.
#
# **Education:**
# - B.S. in Computer Science from XYZ University.
#
# **Skills:**
# - Proficient in Python, JavaScript, React, and SQL.
# Enter the job description for the position you are applying for:
#  SW engineer
# Generated Cover Letter:
# [Your Name]
# [Your Address]
# [City, State, Zip]
# [Your Email]
# [Your Phone Number]
# [Date]
#
# [Employer's Name]
# [Company's Name]
# [Company's Address]
# [City, State, Zip]
#
# Dear [Employer's Name],
#
# I am writing to express my interest in the Software Engineer position at [Company's Name], as advertised [where you found the job listing]. With a Bachelor’s degree in Computer Science from XYZ University and hands-on experience developing web applications using Python and JavaScript, I am excited about the opportunity to contribute to your team.
#
# Throughout my career, I have been committed to creating effective and efficient solutions. My experience in developing web applications has equipped me with a strong foundation in both back-end and front-end technologies, particularly in Python and JavaScript. I have had the pleasure of collaborating with cross-functional teams, which has honed my ability to communicate effectively and ensure timely project delivery. I believe these skills will align well with the collaborative nature of [Company's Name].
#
# Proficiency in React and SQL complements my programming foundation nicely, allowing me to build dynamic user interfaces and manage database interactions with ease. I am always eager to learn new technologies and embrace challenges that come my way.
#
# I am particularly drawn to [Company's Name] because of [specific reason related to the company or its projects]. I admire [any traits, projects, or values of the company], and I see a strong alignment between my skills and the innovative work being done at your organization.
#
# Thank you for considering my application. I look forward to the opportunity to further discuss how my background, skills, and enthusiasms can contribute to the success of your team. Please feel free to contact me at [Your Phone Number] or [Your Email] to schedule a conversation.
#
# Warm regards,
#
# John Doe
#
# [Your LinkedIn Profile or Website, if applicable]
