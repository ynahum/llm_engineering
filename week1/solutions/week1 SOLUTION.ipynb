# %% [markdown]
# # End of week 1 solution
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!
#
# After week 2 you'll be able to add a User Interface to this tool, giving you a valuable application.

# %%
# imports

from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI
import ollama

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

load_dotenv()
openai = OpenAI()

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# prompts

system_prompt = "You are a helpful technical tutor who answers questions about python code, software engineering, data science and LLMs"
user_prompt = "Please give a detailed explanation to the following question: " + question

# %%
# messages

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# %%
# Get gpt-4o-mini to answer, with streaming

stream = openai.chat.completions.create(model=MODEL_GPT, messages=messages,stream=True)
    
response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    response = response.replace("```","").replace("markdown", "")
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# The provided code is a Python expression that uses the `yield from` statement in conjunction with a set comprehension. Let's break down what this code does step by step.
#
# ### Components of the Expression
#
# 1. **Set Comprehension**:
#    python
#    {book.get("author") for book in books if book.get("author")}
#
#    This part creates a set of authors from a collection of `books`. Here's how it works:
#    - **`for book in books`**: This iterates over each item in the `books` iterable. Each `book` is expected to be a dictionary or an object that supports the `get` method.
#    - **`book.get("author")`**: This attempts to retrieve the value associated with the key `"author"` from each `book`.
#    - **`if book.get("author")`**: It serves as a condition to ensure that only books with a non-`None` (or non-empty) author are included in the set. This prevents `None` or empty values from being added to the set.
#    - The result is a set of distinct author names from the `books` collection, because a set inherently filters out duplicate values.
#
# 2. **`yield from`**:
#    python
#    yield from ...
#
#    This expression is typically used within a generator function. The `yield from` statement allows the generator to delegate part of its operations to another iterable (in this case, the set created by the set comprehension). This means that it will yield each item produced by the set one by one.
#
# ### What the Entire Expression Does
# Combining both parts of the expression, we see that:
#
# - The set comprehension collects unique authors from the `books` iterable (ignoring books that have no author).
# - The `yield from` statement allows a generator function to output each author name fetched from the set, which means the function will yield each author as if they were being produced by the current generator.
#
# ### Example Use Case
# Suppose you have a list of book dictionaries like this:
# python
# books = [
#     {"title": "Book A", "author": "Author X"},
#     {"title": "Book B", "author": "Author Y"},
#     {"title": "Book C"},  # No author
#     {"title": "Book D", "author": "Author X"},  # Duplicate author
# ]
#
# Using the expression:
# python
# yield from {book.get("author") for book in books if book.get("author")}
#
# The generator would yield:
# - "Author X"
# - "Author Y"
#
# ### Why Use This Code?
# - **Efficiency**: By using a set comprehension, duplicate authors are automatically filtered out, ensuring that each author is yielded only once.
# - **Clarity**: The use of `yield from` makes the intent clear that we are generating a series of values from another iterable (the set of authors).
# - **Avoiding None/Empty Values**: The filtering ensures that only valid author names contribute to the generator's output.
#
# In summary, this line of code is a concise and efficient way to gather and yield unique authors from a collection of books, ensuring that only those books with valid author entries are considered.

# %%
# Get Llama 3.2 to answer

response = ollama.chat(model=MODEL_LLAMA, messages=messages)
reply = response['message']['content']
display(Markdown(reply))
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpx\_transports\default.py:72, in map_httpcore_exceptions()
#      71 try:
# ---> 72     yield
#      73 except Exception as exc:
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Get Llama 3.2 to answer
# ----> 3 response = ollama.chat(model=MODEL_LLAMA, messages=messages)
#       4 reply = response['message']['content']
#       5 display(Markdown(reply))
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\ollama\_client.py:332, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     288 def chat(
#     289   self,
#     290   model: str = '',
#    (...)
#     297   keep_alive: Optional[Union[float, str]] = None,
#     298 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     299   """
#     300   Create a chat response using the requested model.
#     301
#    (...)
#     330   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     331   """
# --> 332   return self._request(
#     333     ChatResponse,
#     334     'POST',
#     335     '/api/chat',
#     336     json=ChatRequest(
#     337       model=model,
#     338       messages=[message for message in _copy_messages(messages)],
#     339       tools=[tool for tool in _copy_tools(tools)],
#     340       stream=stream,
#     341       format=format,
#     342       options=options,
#     343       keep_alive=keep_alive,
#     344     ).model_dump(exclude_none=True),
#     345     stream=stream,
#     346   )
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\ollama\_client.py:177, in Client._request(self, cls, stream, *args, **kwargs)
#     173         yield cls(**part)
#     175   return inner()
# --> 177 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\ollama\_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     117 def _request_raw(self, *args, **kwargs):
# --> 118   r = self._client.request(*args, **kwargs)
#     119   try:
#     120     r.raise_for_status()
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpx\_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpx\_transports\default.py:235, in HTTPTransport.handle_request(self, request)
#     221 assert isinstance(request.stream, SyncByteStream)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
# --> 235 with map_httpcore_exceptions():
#     236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~\AppData\Local\miniconda3\envs\llms\Lib\site-packages\httpx\_transports\default.py:89, in map_httpcore_exceptions()
#      86     raise
#      88 message = str(exc)
# ---> 89 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it

# %% [markdown]
# # Congratulations!
#
# You could make it better by taking in the question using
# `my_question = input("Please enter your question:")`
#
# And then creating the prompts and making the calls interactively.
